# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
data={
    'ID':[1,2,3,4,5,6,7,8],
    'Name':['Riya','Arjun','Sneha','Rakesh','Aditi','Kiran','Anjali','Manish'],
    'Gender':['F','M','F','M','F','M','F','M'],
    'Age':[17,18,17,19,18,18,17,19],
    'Study_Hours':[3.5,2.0,4.0,1.5,3.8,2.5,4.2,1.0],
    'Attendance(%)':[95,82,98,70,92,85,99,65],
    'Marks_Math':[88,75,90,65,95,78,91,60],
    'Marks_Science':[92,80,89,68,93,75,95,58],
    'Grade':['A','B','A','C','A','B','A','D']
}
df=pd.DataFrame(data)
print(df)
df["Marks_Math"].plot(kind='hist')
x=df["Marks_Math"]
plt.hist(x)
plt.show()
# Out:
#    ID    Name Gender  Age  Study_Hours  Attendance(%)  Marks_Math  \
# 0   1    Riya      F   17          3.5             95          88
# 1   2   Arjun      M   18          2.0             82          75
# 2   3   Sneha      F   17          4.0             98          90
# 3   4  Rakesh      M   19          1.5             70          65
# 4   5   Aditi      F   18          3.8             92          95
# 5   6   Kiran      M   18          2.5             85          78
# 6   7  Anjali      F   17          4.2             99          91
# 7   8  Manish      M   19          1.0             65          60
#
#    Marks_Science Grade
# 0             92     A
# 1             80     B
# 2             89     A
# 3             68     C
# 4             93     A
# 5             75     B
# 6             95     A
# 7             58     D

# %%
import matplotlib.pyplot as plt
plt.hist(df['Marks_Math'])
plt.show()

# %%
a=df['Grade'].value_counts().sort_index()
plt.bar(a.index,a.values)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.boxplot(df['Study_Hours'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22642e98be0>,
#   <matplotlib.lines.Line2D at 0x22642e982b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x22642e98970>,
#   <matplotlib.lines.Line2D at 0x22642e413d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22642e98190>],
#  'medians': [<matplotlib.lines.Line2D at 0x22642e416d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22642e41880>],
#  'means': []}

# %%
plt.hist(df['Study_Hours'])
# Out:
# (array([1., 1., 0., 1., 1., 0., 0., 1., 1., 2.]),
#  array([1.  , 1.32, 1.64, 1.96, 2.28, 2.6 , 2.92, 3.24, 3.56, 3.88, 4.2 ]),
#  <a list of 10 Patch objects>)

# %%
a=df['Gender'].value_counts().sort_index()
plt.pie(a.values, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2264244ea60>,
#   <matplotlib.patches.Wedge at 0x22642c9a3d0>],
#  [Text(6.735557395310444e-17, 1.1, ''),
#   Text(-2.0206672185931328e-16, -1.1, '')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.1021821192326178e-16, -0.6, '50.0%')])

# %%
plt.bar(df['Attendance(%)'],df['ID'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.scatter(df['Study_Hours'],df['Marks_Math'])

# %%
plt.scatter(df['Attendance(%)'],df['Marks_Science'])

# %%
marks=df.groupby('Gender')['Marks_Math'].mean()
plt.bar(marks.index,marks.values)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.plot(df['Name'],df[['Marks_Science','Marks_Math']])
# Out:
# [<matplotlib.lines.Line2D at 0x22642d2b490>,
#  <matplotlib.lines.Line2D at 0x22642c334c0>]

# %%
df.boxplot(column='Marks_Math',by='Grade')
